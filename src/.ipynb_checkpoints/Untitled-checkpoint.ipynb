# %%
import torch
import math
import random
# [hours_studied, hours_slept] → pass(1) or fail(0)

class Neuron:
    g = torch.Generator().manual_seed(2147483647)
    
    def sigmoid(self, act):
        return 1 / (1 + torch.exp(-act))
        
    def __init__(self, nin):
        self.w = [torch.tensor(random.uniform(-1,1), requires_grad=True) for _ in range(nin)]
        self.b = torch.tensor(random.uniform(-1.0,1.0), requires_grad=True)

    def parameters(self):
        return self.w

    def __call__(self, x):
        act = sum((wi*xi for wi,xi in zip(self.w, x)), self.b)
        return self.sigmoid(act)

x = [
    [1, 3],   # fail
    [2, 4],   # fail
    [3, 5],   # pass
    [4, 6],   # pass
    [5, 3],   # pass
    [1, 2],   # fail
    [6, 4],   # pass
    [2, 2],   # fail
]
y = [0, 0, 1, 1, 1, 0, 1, 0]

xs = torch.tensor(x).float()
ys = torch.tensor(y).float()

n = Neuron(2)

# %%
# Loss function
for i in range(50):
    learning_rate = 0.1
    ypred = torch.stack([n(i) for i in xs])
    loss = sum([(y - yp)**2 for y,yp in zip(ys,ypred)])

    for w in n.parameters():
        w.grad=None
    
    loss.backward()
    
    for w in n.parameters():
        w.data -= learning_rate * w.grad
    
    print(loss)
# Out:
# tensor(1.0137, grad_fn=<AddBackward0>)
# tensor(1.0137, grad_fn=<AddBackward0>)
# tensor(1.0137, grad_fn=<AddBackward0>)
# tensor(1.0137, grad_fn=<AddBackward0>)
# tensor(1.0137, grad_fn=<AddBackward0>)
# tensor(1.0137, grad_fn=<AddBackward0>)
# tensor(1.0137, grad_fn=<AddBackward0>)
# tensor(1.0137, grad_fn=<AddBackward0>)
# tensor(1.0137, grad_fn=<AddBackward0>)
# tensor(1.0137, grad_fn=<AddBackward0>)
# tensor(1.0137, grad_fn=<AddBackward0>)
# tensor(1.0137, grad_fn=<AddBackward0>)
# tensor(1.0137, grad_fn=<AddBackward0>)
# tensor(1.0137, grad_fn=<AddBackward0>)
# tensor(1.0137, grad_fn=<AddBackward0>)
# tensor(1.0137, grad_fn=<AddBackward0>)
# tensor(1.0137, grad_fn=<AddBackward0>)
# tensor(1.0137, grad_fn=<AddBackward0>)
# tensor(1.0137, grad_fn=<AddBackward0>)
# tensor(1.0137, grad_fn=<AddBackward0>)
# tensor(1.0137, grad_fn=<AddBackward0>)
# tensor(1.0137, grad_fn=<AddBackward0>)
# tensor(1.0137, grad_fn=<AddBackward0>)
# tensor(1.0137, grad_fn=<AddBackward0>)
# ...

# %%
test = torch.tensor([[4.0, 5.0],  
                    [1.0, 2.0]])
yred = [n(i) for i in test]
print(f"first pre {yred[0]}")
print(f"second pre {yred[1]}")
# Out:
# first pre 1.0
# second pre 0.09964513033628464
